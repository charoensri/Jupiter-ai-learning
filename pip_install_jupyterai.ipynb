# %%
pip install "jupyter-ai==3.0.0b7"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/10.3 MB 6.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/10.3 MB 6.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/10.3 MB 6.7 MB/s eta 0:00:01
#    --------------------- ------------------ 5.5/10.3 MB 6.7 MB/s eta 0:00:01
#    -------------------------- ------------- 6.8/10.3 MB 6.7 MB/s eta 0:00:01
#    ------------------------------- -------- 8.1/10.3 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------ --- 9.4/10.3 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.3/10.3 MB 6.5 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/741.9 kB ? eta -:--:--
#    ---------------------------------------- 741.9/741.9 kB 5.7 MB/s  0:00:00
# ...

# %%
import jupyter_ai
#from jupyter_ai import AIChatbot

# %%
from jupyter_ai import AIChatbot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from jupyter_ai import AIChatbot
#
# ImportError: cannot import name 'AIChatbot' from 'jupyter_ai' (C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages\jupyter_ai\__init__.py)
